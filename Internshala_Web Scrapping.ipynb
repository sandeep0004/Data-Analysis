# %% [markdown]
# # Job Applications webscrapping

# %%
#pip install beautifulsoup4

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
url='https://internshala.com/jobs/data-science-jobs/'

# %%
req=requests.get(url)

# %%
req
# Out:
# <Response [200]>

# %%
content=BeautifulSoup(req.content,'html.parser')
print(content.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
#   <meta content="702141670710132" property="fb:app_id"/>
#   <meta content="website" property="og:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="@Internshala" name="twitter:site"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@internshala" name="twitter:creator"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="#ffffff" name="msapplication-navbutton-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/static/fonts/internshala-icons.woff2?vw3rgh" type="font/woff2"/>
#   <script src="/static/js/web_vitals/web-vitals.umd.js">
#   </script>
#   <script defer="" src="/static/js/includes/common/libraries.2583691470.js">
#   </script>
#   <link href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://internshala.com//favicon.ico?v=5" rel="icon"/>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    window.onerror = function (error, url, line, col, fullError) {
#         error = fullError || error;
#         store_data(error, line);
#     };
#
#     function store_data(error, line) {
#         error = error.stack || error;
#         var url = window.location.href;
#         var browser = get_browser();
#         var browser_name = browser.name;
#         var browser_version = browser.version;
#         var browser_ua = browser.user_agent;
#         var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;
#         // var xhttp = new XMLHttpRequest();
#         // xhttp.onreadystatechange = function () {
#         //     if (this.readyState === 4 && this.status === 200) {
#
#         //     }
#         // };
#         // xhttp.open("POST", "/browser_error/insert_browser_logs", true);
#         // xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         // xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         // xhttp.send(message);
#     }
#
#     function get_browser() {
#         var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#         if (/trident/i.test(M[1])) {
#             tem = /\brv[ :]+(\d+)/g.exec(ua) || [];
#             return {name: 'IE', version: (tem[1] || '')};
#         }
#         if (M[1] === 'Chrome') {
#             tem = ua.match(/\bOPR|Edge\/(\d+)/)
#             if (tem != null) {
#                 return {name: 'Opera', version: tem[1]};
#             }
#         }
#         M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, '-?'];
#         if ((tem = ua.match(/version\/(\d+)/i)) != null) {
#             M.splice(1, 1, tem[1]);
#         }
#         return {
#             name: M[0],
#             version: M[1],
#             user_agent: ua
#         };
#     }
#   </script>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    var os_type = "";
#         var browser_name = '';
#         var is_android = 0;
#         var is_mobile = 1;
#         var l_cookie = "";
#         var view = "internship/search/search";
#         var mainRole = "guest";
#         var to_show_account_activated_message = false;
#         var to_show_subscription_activated_message = false;
#         var location_autocomplete_min_length = 3;
#         var fresherJobsMinCtc = 2;
#         var show_maintenance_ribbon = false;
#         var maintenance_ribbon_message = "";
#         var base_url = 'https://internshala.com/';
#         var job_discount_campaign_type = "";
#         var is_g_recaptcha = "6LdwW1ckAAAAAKcsi3VSrXg49B7GXfisCJDmI9kf";
#         var error_ribbon_support_email = "support@internshala.com";
#   </script>
#   <title>
#    137 Data Science Jobs in Jun 2023 | Internshala
#   </title>
#   <meta content="Apply to 137 Data Science Jobs on Internshala. Explore the latest  job vacancies &amp; openings in top companies and get your dream job today!" name="description"/>
#   <meta content="137 Data Science Jobs in Jun 2023 | Internshala" property="og:title"/>
#   <meta content="Apply to 137 Data Science Jobs on Internshala. Explore the latest  job vacancies &amp; openings in top companies and get your dream job today!" property="og:description"/>
#   <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="og:image"/>
#   <meta content="137 Data Science Jobs in Jun 2023 | Internshala" name="twitter:title"/>
#   <meta content="Apply to 137 Data Science Jobs on Internshala. Explore the latest  job vacancies &amp; openings in top companies and get your dream job today!" name="twitter:description"/>
#   <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="twitter:image:src"/>
#   <link href="/static/css/internship/search/search.1687763152.css" rel="stylesheet" type="text/css"/>
#   <script defer="" src="/static/js/combined/common_form.1687759743.js" type="text/javascript">
#   </script>
#   <script defer="" src="/static/js/combined/internship-search.1687763164.js" type="text/javascript">
#   </script>
#   <script defer="" src="/static/js/subscribe/popup.1643608951.js" type="text/javascript">
#   </script>
#   <script defer="" src="https://www.google.com/recaptcha/enterprise.js?render=6LdwW1ckAAAAAKcsi3VSrXg49B7GXfisCJDmI9kf" type="text/javascript">
#   </script>
#   <link href="/jobs/data-science-jobs/page-2" rel="next"/>
#   <link href="https://internshala.com/jobs/data-science-jobs/" rel="canonical"/>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    function sendToGTM(name, delta, id) {
#         if (typeof dataLayer == 'undefined') {
#             return;
#         }
#         // Assumes the global `dataLayer` array exists, see:
#         // https://developers.google.com/tag-manager/devguide
#         dataLayer.push({
#             event: 'web-vitals',
#             event_category: 'Web Vitals',
#             event_action: name.name,
#             // Google Analytics metrics must be integers, so the value is rounded.
#             // For CLS the value is first multiplied by 1000 for greater precision
#             // (note: increase the multiplier for greater precision if needed).
#             event_value: Math.round(name.name === 'CLS' ? name.delta * 1000 : name.delta),
#             // The 'id' value will be unique to the current page load. When sending
#             // multiple values from the same page (e.g. for CLS), Google Analytics can
#             // compute a total by grouping on this ID (note: requires `eventLabel` to
#             // be a dimension in your report).
#             event_label: name.id,
#         });
#     }
#     webVitals.getCLS(sendToGTM);
#     webVitals.getFID(sendToGTM);
#     webVitals.getLCP(sendToGTM);
#     webVitals.getFCP(sendToGTM);
#     webVitals.getTTFB(sendToGTM);
#   </script>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    //    window.addEventListener('load', function() {
# //        store_session_data();
# //    });
#
# //    window.addEventListener('DOMContentLoaded', function() {
# //        store_session_data();
# //    });
#
#     var pdcVersion = "0";
#     var toMakeInitialRequest = 1;
#     if (toMakeInitialRequest == 1) {
#         store_session_data();
#     }
#
#     function store_session_data() {
#         var message = "device=" + getDeviceType();
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#                 var responseText = this.responseText;
#                 try {
#                     data = JSON.parse(responseText);
#                     if (data.success) {
#                         if(data.toMakeUpdateRequest) {
#                             update_session_data();
#                         }
#                     } else {
#                         //TODO
#                     }
#                 } catch (e) {
#                     throw_error(e);
#                 }
#             }
#         };
#
#         xhttp.open("POST", "/info/storeData", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function update_session_data() {
#         var message = "";
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#             }
#         };
#
#         xhttp.open("POST", "/info/updateDeviceCookieVersion", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function getDeviceType() {
#         var device;
#         if (typeof isMobile !== 'undefined') {
#             if (isMobile === '1') {
#                 device = "mobile";
#             } else {
#                 device = "desktop";
#             }
#         } else {
#             device = "NA";
#         }
#
#         return device;
#     }
#   </script>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#   </script>
#  </head>
#  <body>
#   <div id="wrapper">
#    <!-- ribbon -->
#    <div class="notification" id="error">
#    </div>
#    <div class="notification notification_general" id="general_notification" style="display: none">
#    </div>
#    <div id="custom_notification_parent">
#     <div class="notification notification_general" id="custom_notification" style="display: none">
#     </div>
#    </div>
#    <!-- modal - error message -->
#    <div class="modal fade in internshala-modal" id="error_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container error_image">
#         <div class="image">
#         </div>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - success message -->
#    <div class="modal fade in internshala-modal" id="success_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container success_image">
#         <div class="image">
#         </div>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Cancel
#          </button>
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - success message -->
#    <div class="modal fade in internshala-modal" id="success_modal_dual_button" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container success_image">
#         <div class="image">
#         </div>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - alert message -->
#    <div class="modal fade in internshala-modal" id="alert_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container alert_image">
#         <div class="image">
#         </div>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!--- confirmation modal-->
#    <div class="modal fade in internshala-modal confirmation_modal" id="confirmation_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="message_container">
#         <div class="text-heading heading_4_5">
#         </div>
#         <div class="text-message body-main">
#         </div>
#         <div class="button_container">
#          <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Cancel
#          </button>
#          <a class="btn btn-primary modal_primary_btn yes-button close_action" data-dismiss="modal">
#           Yes
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="loading_image">
#    </div>
#    <div class="nav_dropdown_backdrop">
#    </div>
#    <noscript>
#     <div class="notification notification_js_disabled" style="display: block;">
#      Oops, your browser does not support Javascript. Please use Internshala in another browser.
#     </div>
#    </noscript>
#    <div class="toast internshala-toast loading_toast" id="loading_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#       Loading, please wait...
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast general_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast error_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast black_bottom_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body body-main">
#      </div>
#     </div>
#    </div>
#    <div class="popover_overlay">
#    </div>
#    <div class="chat_notification_loading_image" style="display: none;">
#    </div>
#    <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal" id="login-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <i aria-hidden="true" class="ic-24-cross">
#         </i>
#        </button>
#       </div>
#       <div class="modal-body">
#        <div id="user-menu-container">
#         <div id="user-menu">
#          <div class="row">
#           <div class="col-xs-6 col-6 user-menu-item active login_student" id="modal_student">
#            Student
#           </div>
#           <div class="col-xs-6 col-6 user-menu-item login_employer" id="modal_employer">
#            Employer / T&amp;P
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="google_login" href="/login/get_google">
#         <div id="google-button-container">
#          <div class="google_image_container">
#           <div class="google_logo">
#           </div>
#          </div>
#          <div class="google_content">
#           Login with Google
#          </div>
#         </div>
#        </a>
#        <div class="helper">
#         <div class="text2">
#          <p>
#           OR
#          </p>
#         </div>
#         <div class="border">
#         </div>
#        </div>
#        <form id="modal-login-form" method="POST" role="form">
#         <input name="csrf_test_name" type="hidden" value="2991e40a72aff9a1247c6fa26117e9dc"/>
#         <div class="form-group">
#          <label class="control-label" for="email">
#           Email
#          </label>
#          <input class="form-control" id="modal_email" name="email" placeholder="john@example.com" tabindex="1" type="email"/>
#         </div>
#         <div class="form-group">
#          <label class="control-label" for="password">
#           Password
#          </label>
#          <input class="form-control" id="modal_password" name="password" placeholder="Must be atleast 6 characters" tabindex="2" type="password"/>
#         </div>
#         <div class="forgot_password">
#          <a href="/login/forgot_password" id="forgot-password">
#           Forgot password?
#          </a>
#         </div>
#         <div class="form-group">
#          <button class="btn btn-primary" id="modal_login_submit" tabindex="3" type="submit">
#           Login
#          </button>
#         </div>
#         <div class="form-group new_to_internshala">
#          <label>
#           New to Internshala? Register (
#           <a href="/registration/student">
#            Student
#           </a>
#           /
#           <a href="/post-job">
#            Company
#           </a>
#           )
#          </label>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- Login modal - error message for employers blocked -->
#    <div aria-hidden="true" class="modal fade" id="employer_blocked_error_modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="heading">
#        Your account is put on hold.
#        <i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal" style="cursor: pointer;float:right">
#        </i>
#       </div>
#       <div class="heading1">
#        Your account is put on hold.
#        <i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal1" style="cursor: pointer;float:right">
#        </i>
#       </div>
#       <div class="main_content">
#        <div class="line1">
#        </div>
#        <div class="sub_heading">
#         What happened?
#        </div>
#        <div>
#         We have determined that this account is violation of Internshala's
#         <span class="primary_color">
#          <a href="https://internshala.com/terms">
#           rules
#          </a>
#         </span>
#         .
#        </div>
#        <div class="content_specially_for">
#         Specifically for,
#        </div>
#        <div class="error_heading" id="heading_content1">
#        </div>
#        <div class="error_content_1" id="error_content1">
#        </div>
#        <div class="error_heading" id="heading_content2">
#        </div>
#        <div class="error_content_1" id="error_content2">
#        </div>
#        <div class="error_content_2">
#         If you wish to appeal this, or seek further clarification, please contact our team at
#         <span class="primary_color">
#          <a href="mailto:complaints@internshala.com">
#           complaints@internshala.com
#          </a>
#         </span>
#        </div>
#        <div class="line2">
#        </div>
#        <div class="icon_container">
#         <i class="ic-24-alert-circle">
#         </i>
#         <div class="icon_content">
#          If this has happened by mistake, it will automatically be reverted within 24 hours.
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="header_container container-fluid" id="header">
#     <div class="max-width-container">
#      <div class="layer">
#      </div>
#      <div class="sidenav" id="mySidenav">
#       <div class="ham_menu_items_container guest">
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/internships">
#           Internships
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/jobs">
#           Jobs
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a class="online-training-link" href="https://trainings.internshala.com/?utm_source=is_web_internshala_ham">
#           Courses
#           <div class="contest">
#            80% OFF
#           </div>
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a class="specialization-training-link" href="https://trainings.internshala.com/?utm_source=is_web_hamburger#placement-and-job-guarantee-courses">
#           <span class="specialization-training-title">
#            <span>
#             Placement Guarantee courses
#            </span>
#            <!--                            <span class="specialization-training-subtitle"></span>-->
#           </span>
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/contact">
#           Contact Us
#          </a>
#         </div>
#        </div>
#        <hr class="ham_line_break"/>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/registration/student">
#           Register - As a Student
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/post-job">
#           Register - As an Employer
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items without_link">
#         <div class="ham_main_heading home_page_login_button" data-target="#login-modal" data-toggle="modal" id="ham_login_button">
#          Login
#         </div>
#        </div>
#       </div>
#      </div>
#      <nav class="navbar navbar-expand-md">
#       <div class="brand_container">
#        <div class="hamburger_menu">
#         <i class="ic-24-web-hamburger" id="hamburger_menu_key">
#         </i>
#         <span class="offer_hamburger_dot" id="offer_hamburger_dot">
#         </span>
#        </div>
#        <a class="navbar-brand" href="/">
#         <div class="internshala-logo">
#         </div>
#        </a>
#       </div>
#       <div class="navbar_header_register navbar_mobile" id="main-navbar-header">
#        <div id="register-container">
#         <div id="register-container-inner">
#          <div class="btn-group" id="">
#           <a href="/registration/student">
#            <button class="btn btn-primary" type="button">
#             Register
#            </button>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="collapse navbar-collapse navbar_desktop">
#        <ul class="navbar-nav nav_menu_container">
#         <li class="nav-item internship_container_hover dropdown dropdown-hover dropdown_backdrop">
#          <a class="nav-link dropdown-toggle internship_link" href="/internships" id="internships_new_superscript">
#           Internships
#           <i class="is_icon_header ic-24-filled-down-arrow">
#           </i>
#          </a>
#          <div class="dropdown-menu dropdown-menu-center menu_dropdown guest_dropdown" id="internships-dropdown">
#           <div class="dropdown-inner">
#            <div class="internship-menu">
#             <div class="menu-link-main-1" data-value="1">
#              <div class="menu-heading menu-heading-hover">
#               <span>
#                Top Locations
#               </span>
#              </div>
#             </div>
#             <div class="menu-link-main-2" data-value="2">
#              <div class="menu-heading">
#               <span>
#                Profile
#               </span>
#              </div>
#             </div>
#             <div class="menu-link-main-3" data-value="3">
#              <div class="menu-heading">
#               <span>
#                Top Categories
#               </span>
#              </div>
#             </div>
#             <div class="menu-link-main-4" data-value="4">
#              <div class="menu-heading">
#               <span>
#                Explore More Internships
#               </span>
#              </div>
#             </div>
#             <div class="menu-link-main-5" data-value="5">
#              <div class="menu-heading">
#               <span>
#                Placement Guarantee Courses
#                <span class="tag x-small">
#                 NEW
#                </span>
#               </span>
#              </div>
#             </div>
#            </div>
#            <div class="internship-sub-menu">
#             <div class="sub-menu-link-content-1 active-container sub-menu-content-container">
#              <div class="internship-sub-scroll">
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/work-from-home-internships" style="">
#                Work from Home
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-bangalore" style="">
#                Internship in Bangalore
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-delhi" style="">
#                Internship in Delhi
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-hyderabad" style="">
#                Internship in Hyderabad
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-mumbai" style="">
#                Internship in Mumbai
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-chennai" style="">
#                Internship in Chennai
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-pune" style="">
#                Internship in Pune
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-kolkata" style="">
#                Internship in Kolkata
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-jaipur" style="">
#                Internship in Jaipur
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/international-internship" style="">
#                International Internship
#               </a>
#               <a class="item_link view_all" href="https://internshala.com/internships/">
#                View all internships
#               </a>
#              </div>
#             </div>
#             <div class="sub-menu-link-content-2 sub-menu-content-container">
#              <div class="internship-sub-scroll">
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/computer-science-internship" style="">
#                Computer Science Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/marketing-sales-internship" style="">
#                Marketing Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/finance-internship" style="">
#                Finance Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/graphic-design-internship" style="">
#                Graphic Design Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/architecture-internship" style="">
#                Architecture Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/mechanical-internship" style="">
#                Mechanical Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/hr-internship" style="">
#                HR Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/digital-marketing-internship" style="">
#                Digital Marketing Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/law-internship" style="">
#                Law Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/electronics-internship" style="">
#                Electronics Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/content-writing-internship" style="">
#                Content Writing Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/civil-internship" style="">
#                Civil Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/campus-ambassador-internship?utm_source=header" style="">
#                Campus Ambassador Program
#               </a>
#               <a class="item_link view_all" href="https://internshala.com/internships/">
#                View all internships
#               </a>
#              </div>
#             </div>
#             <div class="sub-menu-link-content-3 sub-menu-content-container">
#              <div class="internship-sub-scroll">
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/engineering-internship" style="">
#                Engineering Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/mba-internship" style="">
#                Business/MBA Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/part-time-jobs" style="">
#                Part-Time Jobs/Internships
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/humanities-internship" style="">
#                Humanities Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/science-internship" style="">
#                Science Internship
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships/ppo-true" style="">
#                Internships with Job Offer
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships-for-women?utm_source=ifw_is_dropdown" style="">
#                Internships for Women
#               </a>
#               <a class="item_link view_all" href="https://internshala.com/internships/">
#                View all internships
#               </a>
#              </div>
#             </div>
#             <div class="sub-menu-link-content-4 sub-menu-content-container">
#              <div class="internship-sub-scroll">
#               <a class="item_link internship_item_location" href="https://internshala.com/internships-by-category/?utm_source=is_menu_dropdown" style="">
#                Internships by Category
#               </a>
#               <a class="item_link internship_item_location" href="https://internshala.com/internships-by-location/?utm_source=is_menu_dropdown" style="">
#                Internships by Location
#               </a>
#              </div>
#             </div>
#             <div class="sub-menu-link-content-5 sub-menu-content-container">
#              <div class="internship-sub-scroll">
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/full-stack-web-development-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Full Stack Development Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/data-science-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Data Science Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/human-resource-management-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Human Resource Management Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/digital-marketing-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Digital Marketing Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/electric-vehicles-placement-guarantee-course?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Electric Vehicle Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/sales-and-business-development-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Business Development Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/ui-ux-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                UI/UX Course
#               </a>
#               <a class="item_link internship_item_location" href="https://trainings.internshala.com/product-management-specialization?utm_source=is_web_internship-menu-dropdown" style="" target="_blank">
#                Product Management Course
#               </a>
#              </div>
#             </div>
#            </div>
#           </div>
#          </div>
#         </li>
#         <li class="nav-item training_container_hover dropdown dropdown-hover dropdown_backdrop nav-links">
#          <a class="nav-link dropdown-toggle trainings_link menu-link" href="https://trainings.internshala.com/?utm_source=is_web_internshala-menu-dropdown1" id="trainings_dropdown_link" rel="noopener" target="_blank">
#           Courses
#           <div class="contest">
#            80% OFF
#           </div>
#           <i class="is_icon_header ic-24-filled-down-arrow">
#           </i>
#          </a>
#          <div class="training-dropdown-content">
#           <div class="training-box student">
#            <div class="menu-link-main-1 training-menu">
#             <div class="menu-heading menu-heading-hover">
#              <span>
#               Most Popular
#              </span>
#             </div>
#            </div>
#            <div class="sub-menu-link-content-1 sub-menu">
#             <div class="training-sub-scroll">
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/web-development-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Web Development
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/python-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Programming with Python
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/digital-marketing-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Digital Marketing
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/machine-learning-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Machine Learning
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/excel-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Advanced Excel
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/autocad-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               AutoCAD
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/data-science-beginner-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Data Science
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/c-plus-plus-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Programming with C and C++
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/financial-modeling-valuation-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Financial Modeling and Valuation
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/android-course/?utm_source=is_web_internshala-menu-dropdown-most-popular" rel="noopener" style="" target="_blank">
#               Android App Development
#              </a>
#             </div>
#            </div>
#            <div class="menu-link-main-2 training-menu">
#             <div class="menu-heading menu-heading-hover">
#              <span>
#               Programming
#              </span>
#             </div>
#            </div>
#            <div class="sub-menu-link-content-2 sub-menu hide-the-item">
#             <div class="training-sub-scroll">
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/web-development-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Web Development
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/python-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Programming with Python
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/c-plus-plus-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Programming with C and C++
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/java-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Core Java
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/android-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Android App Development
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/hacking-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Ethical Hacking
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/react-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               React
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/data-structures-algorithms-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Data Structures &amp; Algorithms
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/clinical-trials-analysis-reporting-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Clinical Trials Analysis &amp; Reporting
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/matlab-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               MATLAB
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/software-testing-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Software Testing
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/aws-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Cloud Computing with AWS
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/plc-programming-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               PLC Programming
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/product-management-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Product Management
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/nodejs-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Node JS
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/sas-programming-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               SAS Programming
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/angular-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Angular
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/ar-vr-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               AR/VR
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/git-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Git &amp; GitHub
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/voice-apps-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Voice App Development
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/how-to-ace-coding-interviews-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               How to Ace Coding Interviews
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/full-stack-web-development-specialization/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Full Stack Development Course
#               <div class="tag x-small">
#                NEW
#               </div>
#              </a>
#             </div>
#            </div>
#            <div class="menu-link-main-3 training-menu">
#             <div class="menu-heading menu-heading-hover">
#              <span>
#               Business &amp; Management
#              </span>
#             </div>
#            </div>
#            <div class="sub-menu-link-content-3 sub-menu hide-the-item">
#             <div class="training-sub-scroll">
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/digital-marketing-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Digital Marketing
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/excel-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Advanced Excel
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/financial-modeling-valuation-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Financial Modeling and Valuation
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/business-analytics-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Business Analytics
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/hr-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Human Resource Management
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/business-communication-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Business Communication Skills
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/stock-market-trading-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Stock Market Trading
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/tally-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Tally
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/sql-data-analytics-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               SQL for Data Analytics
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/hr-advanced-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Advanced Human Resource Management
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/product-management-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Product Management
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/personal-finance-101-course/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Personal Finance 101
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/digital-marketing-specialization/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Digital Marketing Course
#              </a>
#              <a class="sub-link sub-menu-common" href="https://trainings.internshala.com/human-resource-management-specialization/?utm_source=is_web_internshala-menu-dropdown" rel="noopener" style="" target="_blank">
#               Human Resource Management Course
#              </a>
# ...
#              Digital Marketing
#             </a>
#            </div>
#           </div>
#           <div id="trainings_internshala_center">
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/machine-learning-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              Machine Learning
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/excel-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              Advanced Excel
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/autocad-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              AutoCAD
#             </a>
#            </div>
#           </div>
#           <div id="trainings_internshala_right">
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/data-science-beginner-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              Data Science
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/c-plus-plus-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              Programming with C and C++
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="https://trainings.internshala.com/financial-modeling-valuation-course/?utm_source=is_web_is-footer" rel="noopener" target="_blank">
#              Financial Modeling and Valuation
#             </a>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column mobile-footer-991" id="jobs_mobile">
#         <div class="footer-list">
#          <div class="footer-list-heading">
#           Jobs
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs-by-category/?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs by Category
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs-by-location/?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs by Location
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/?utm_source=is_footer" rel="noopener" target="_blank">
#            View all jobs
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column desktop-footer-1255" id="about-us-container">
#         <div class="footer-list">
#          <div class="d-none d-lg-block footer-list-heading">
#           About Internshala
#          </div>
#          <div class="footer-link-conatiner">
#           <div id="about_internshala_left">
#            <div class="footer-list-item">
#             <a href="/about_us">
#              About us
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="/careers">
#              We're hiring
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="/post-job?utm_source=ISfooter">
#              Hire interns for your company
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="http://blog.internshala.com/internshala-editorials/team-diary/" target="_blank">
#              Team Diary
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="https://blog.internshala.com/?utm_source=IS_footer" target="_blank">
#              Blog
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="/products_services">
#              Our Services
#             </a>
#            </div>
#           </div>
#           <div id="about_internshala_center">
#            <div class="footer-list-item">
#             <a href="/terms">
#              Terms &amp; Conditions
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="/privacy">
#              Privacy
#             </a>
#            </div>
#            <div class="footer-list-item">
#             <a href="/contact">
#              Contact us
#             </a>
#            </div>
#           </div>
#           <div id="about_internshala_right">
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="footer-middle-section">
#        <div class="footer-column desktop-footer-1255" id="jobs_by_places">
#         <div class="footer-list">
#          <div class="footer-list-heading">
#           Jobs by Places
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-delhi?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Delhi
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-mumbai?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Mumbai
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-bangalore?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Bangalore
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-jaipur?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Jaipur
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-kolkata?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Kolkata
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-hyderabad?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Hyderabad
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-pune?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Pune
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-chennai?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Chennai
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/jobs-in-lucknow?utm_source=is_footer" rel="noopener" target="_blank">
#            Jobs in Lucknow
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs-by-location/?utm_source=is_footer" rel="noopener" target="_blank">
#            View all jobs
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column desktop-footer-1255" id="jobs_by_stream">
#         <div class="footer-list">
#          <div class="footer-list-heading">
#           Jobs by Stream
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/marketing-sales-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Marketing jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/content-writing-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Content writing jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/web-development-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Web development jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/marketing-sales-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Sales jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/finance-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Finance jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/digital-marketing-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Digital Marketing jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/computer-science-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Computer Science jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/graphic-design-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Graphic Design jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs/data-science-jobs?utm_source=is_footer" rel="noopener" target="_blank">
#            Data Science jobs
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://internshala.com/jobs-by-category/?utm_source=is_footer" rel="noopener" target="_blank">
#            View all jobs
#           </a>
#          </div>
#         </div>
#        </div>
#        <div id="trainings-container">
#        </div>
#        <div id="dummy-container">
#        </div>
#       </div>
#       <div id="footer-about-us-container">
#        <div class="footer-column" id="about_internshala_left">
#         <div class="footer-list">
#          <div class="footer-list-item">
#           <a href="/about_us">
#            About us
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/careers">
#            We're hiring
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/post-job?utm_source=ISfooter">
#            Hire interns for your company
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column" id="about_internshala_center">
#         <div class="footer-list">
#          <div class="footer-list-item">
#           <a href="http://blog.internshala.com/internshala-editorials/team-diary/" target="_blank">
#            Team Diary
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://blog.internshala.com/?utm_source=IS_footer" target="_blank">
#            Blog
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/products_services">
#            Our Services
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column" id="about_internshala_right">
#         <div class="footer-list">
#          <div class="footer-list-item">
#           <a href="/terms">
#            Terms &amp; Conditions
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/privacy">
#            Privacy
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/contact">
#            Contact us
#           </a>
#          </div>
#         </div>
#        </div>
#        <div id="dummy-container-1">
#        </div>
#        <div id="dummy-container-2">
#        </div>
#       </div>
#       <div id="footer-bottom">
#        <a href="https://play.google.com/store/apps/details?id=com.internshala.app&amp;referrer=utm_source%3Dplay_footer" target="_blank">
#         <div class="footer-list-item" id="android_app_container">
#          <i class="ic-24-playstore">
#          </i>
#          <span>
#           Get Android App
#          </span>
#         </div>
#        </a>
#        <div id="social_media_container">
#         <a class="social_media_link_footer" href="https://www.instagram.com/internshala/?utm_source=IS_footer" target="_blank">
#          <i class="ic-24-instagram">
#          </i>
#         </a>
#         <a class="social_media_link_footer" href="https://twitter.com/Internshala?utm_source=IS_footer" target="_blank">
#          <i class="ic-24-twitter">
#          </i>
#         </a>
#         <a class="social_media_link_footer" href="https://www.youtube.com/c/internshalaofficial?utm_source=IS_footer" target="_blank">
#          <i class="ic-24-filled-youtube">
#          </i>
#         </a>
#         <a class="social_media_link_footer" href="https://www.linkedin.com/company/internshala/?utm_source=is-footer" target="_blank">
#          <i class="ic-24-linkedin">
#          </i>
#         </a>
#        </div>
#        <div class="" id="copyright">
#         © Copyright 2023 Internshala
#        </div>
#        <div class="clear">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <nav class="mobile-bottom-nav">
#    <div class="mobile_bottom_nav_container">
#     <div class="mobile_bottom_nav_item">
#      <a class="mobile_bottom_nav_item_content" href="/?utm_source=bottom_navigaton" id="home-nav">
#       <i class="ic-24-home-v2">
#       </i>
#       <div class="content">
#        Home
#       </div>
#      </a>
#     </div>
#     <div class="mobile_bottom_nav_item">
#      <a class="mobile_bottom_nav_item_content" href="/internships/?utm_source=bottom_navigaton" id="internships-nav">
#       <i class="ic-24-plane-v2">
#       </i>
#       <div class="content">
#        Internships
#       </div>
#      </a>
#     </div>
#     <div class="mobile_bottom_nav_item">
#      <div class="top_border">
#      </div>
#      <a class="mobile_bottom_nav_item_content active" href="/jobs/?utm_source=bottom_navigaton" id="jobs-nav">
#       <i class="ic-24-briefcase-v2">
#       </i>
#       <div class="content">
#        Jobs
#       </div>
#      </a>
#     </div>
#     <div class="mobile_bottom_nav_item">
#      <a class="mobile_bottom_nav_item_content" href="https://trainings.internshala.com/?utm_source=is_web_bottom_navigation" id="courses-nav">
#       <div class="amber_dot" id="nav_bar_bottom_amber_dot">
#       </div>
#       <i class="ic-24-trainings">
#       </i>
#       <div class="content">
#        Courses
#       </div>
#      </a>
#     </div>
#    </div>
#   </nav>
#   <!-- Google Code for Adwords Conversion Page
# In your html page, add the snippet and call
# goog_report_conversion when someone clicks on the
# chosen link or button. -->
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    /* <![CDATA[ */
#   goog_snippet_vars = function() {
#     var w = window;
#     w.google_conversion_id = 971396886;
#     w.google_conversion_label = "2vuUCPXQomcQlq6ZzwM";
#     w.google_remarketing_only = false;
#     w.google_conversion_value = 0;
#   }
#   // DO NOT CHANGE THE CODE BELOW.
#   goog_report_conversion = function(url) {
#     goog_snippet_vars();
#     window.google_conversion_format = "3";
#     var opt = new Object();
#     opt.onload_callback = function() {
#     if (typeof(url) != 'undefined') {
#       window.location = url;
#     }
#   }
#   var conv_handler = window['google_trackConversion'];
#   if (typeof(conv_handler) == 'function') {
#     conv_handler(opt);
#   }
# }
# /* ]]> */
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion_async.js" type="text/javascript">
#   </script>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    /* <![CDATA[ */
#     var google_conversion_id = 981478532;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/981478532/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1">
#     </img>
#    </div>
#   </noscript>
#   <script nonce="sHJotWekTlSA0afXeBekwQ==">
#    setTimeout(function() {
#             var loading_toast = document.getElementById("loading_toast");
#             if (typeof loading_toast !== 'undefined' && loading_toast) {
#                 loading_toast.style.display = "block";
#             }
#         }, 2000);
#   </script>
#  </body>
# </html>

# %%
# jobs

# %%
jobs=content.find_all('div',{'class':'company'})

# %%
print(jobs)
# Out:
# [<div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-analyst-fresher-jobs-in-guwahati-at-primary-healthtech1687943819">Data Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-primary-healthtech">
#                         Primary Healthtech                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-artificial-intelligence-ai-executive-fresher-jobs-at-buddha-education-association-incorporation1687953767">Artificial Intelligence (AI) Executive</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-buddha-education-association-incorporation">
#                         Buddha Education Association Incorporation                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-data-scientist-fresher-jobs-at-buddha-education-association-incorporation1687953589">Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-buddha-education-association-incorporation">
#                         Buddha Education Association Incorporation                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-data-scientist-fresher-jobs-at-shubh-international1687951158">Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-shubh-international">
#                         Shubh International                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-research-analyst-fresher-jobs-at-jade-business-services1687760238">Research Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-jade-business-services">
#                         Jade Business Services                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/research-assistant-fresher-jobs-in-mumbai-at-indian-institute-of-technology-bombay1687844046">Research Assistant</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-indian-institute-of-technology%2C-bombay">
#                         Indian Institute Of Technology, Bombay                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/business-analyst-fresher-jobs-in-bangalore-at-vumonic-datalabs1687788044">Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-vumonic-datalabs">
#                         Vumonic Datalabs                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-computer-vision-nlp-ai-engineer-fresher-experienced-fresher-jobs-at-productize-technologies1687639513">Computer Vision &amp; NLP - AI Engineer (Fresher/Experienced)</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-productize-technologies">
#                         Productize Technologies                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/business-analyst-fresher-jobs-in-hyderabad-at-future-skills1687764682">Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-future-skills">
#                         Future Skills                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/behavioral-data-scientist-fresher-jobs-in-hyderabad-at-future-skills1687763990">Behavioral Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-future-skills">
#                         Future Skills                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-machine-learning-engineer-fresher-jobs-at-persist-ventures1687744554">Machine Learning Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-persist-ventures">
#                         Persist Ventures                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/machine-learning-engineer-fresher-jobs-in-delhi-at-outscaleai1687455309">Machine Learning Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-outscale-ai">
#                         Outscale.ai                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/business-analyst-fresher-jobs-in-nagpur-at-arth-venture-partners1687357828">Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-arth-venture-partners">
#                         Arth Venture Partners                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/junior-business-analyst-fresher-jobs-in-bangalore-at-singularium-technologies-private-limited1687433604">Junior Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-singularium-technologies-private-limited">
#                         Singularium Technologies Private Limited                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/executive-analyst-operations-fresher-jobs-in-delhi-gurgaon-at-pro-india1687500091">Executive - Analyst &amp; Operations</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-pro-india">
#                         Pro India                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/associate-data-scientist-fresher-jobs-in-multiple-locations-at-softsensorai1687495965">Associate Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-softsensor-ai">
#                         Softsensor.ai                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/machine-learning-developer-python-fresher-jobs-in-gurgaon-at-warewe-consultancy-private-limited1687437844">Machine Learning Developer (Python)</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-warewe-consultancy-private-limited">
#                         Warewe Consultancy Private Limited                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/transforming-india-initiative-reimagine-responsible-enterprises-fellow-fresher-jobs-in-hyderabad-at-access-livelihoods1687172583">Transforming India Initiative - Reimagine Responsible Enterprises Fellow</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-access-livelihoods">
#                         Access Livelihoods                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/production-technician-fresher-jobs-in-bhiwandi-at-contendre-greenergy-private-limited1687171358">Production Technician</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-contendre-greenergy-private-limited">
#                         Contendre Greenergy Private Limited                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-scientist-fresher-jobs-in-mumbai-at-blobcity1686639916">Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-blobcity">
#                         BlobCity                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-scientist-fresher-jobs-in-pune-at-areete-business-solutions1687175081">Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-areete-business-solutions">
#                         Areete Business Solutions                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/financial-data-analyst-fresher-jobs-in-gurgaon-at-nirvana-solutions1687174330">Financial Data Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-nirvana-solutions">
#                         Nirvana Solutions                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/business-development-associate-fresher-jobs-in-bangalore-at-talentxo1687169169">Business Development Associate</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-talentxo">
#                         TalentXO                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-science-machine-learning-trainer-fresher-jobs-in-multiple-locations-at-mentorrbuddy1686980863">Data Science &amp; Machine Learning Trainer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-mentorrbuddy">
#                         Mentorrbuddy                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/technical-research-engineer-fresher-jobs-in-bangalore-at-avrutti1686932988">Technical Research Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-avrutti">
#                         Avrutti                     </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/junior-java-developer-fresher-jobs-in-pune-nagpur-at-ekatra1686912909">Junior Java Developer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-ekatra">
#                         Ekatra                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-scientist-educationist-fresher-jobs-in-hyderabad-at-future-skills1687264019">Data Scientist Educationist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-future-skills">
#                         Future Skills                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-junior-machine-learning-specialist-fresher-jobs-at-acadbuddy-llp1686738071">Junior Machine Learning Specialist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-acadbuddy-llp">
#                         Acadbuddy LLP                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/machine-learning-engineer-fresher-jobs-in-bangalore-at-wildly-tech-private-limited1686835939">Machine Learning Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-wildly-tech-private-limited">
#                         Wildly Tech Private Limited                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/omni-sport-leader-fresher-jobs-in-zirakpur-at-decathlon-sports-india1686731271">OMNI SPORT LEADER</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-decathlon-sports-india">
#                         Decathlon Sports India                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/python-ai-ml-engineer-fresher-jobs-in-ahmedabad-at-hops-healthcare1686720946">Python (AI/ML) Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-hops-healthcare">
#                         HOPS HEALTHCARE                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/associate-business-analyst-fresher-jobs-in-bangalore-at-akrity-computing1686683739">Associate Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-akrity-computing">
#                         Akrity Computing                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/it-data-visualization-trainee-fresher-jobs-in-chennai-at-studymonk1687169748">IT Data Visualization Trainee</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-studymonk">
#                         StudyMonk                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/it-data-center-operations-associate-fresher-jobs-in-chennai-at-studymonk1687168971">IT Data Center Operations Associate</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-studymonk">
#                         StudyMonk                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/quality-assurance-analyst-fresher-jobs-in-chennai-at-studymonk1687160715">Quality Assurance Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-studymonk">
#                         StudyMonk                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/database-building-management-associate-fresher-jobs-in-jaipur-at-ipics1686633730">Database Building/Management Associate</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-ipics">
#                         IPics                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/it-business-intelligence-analyst-fresher-jobs-in-chennai-at-studymonk1687159664">IT Business Intelligence Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-studymonk">
#                         StudyMonk                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-engineer-fresher-jobs-in-chennai-at-studymonk1687155547">Data Engineer</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-studymonk">
#                         StudyMonk                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/remote-techical-business-analyst-fresher-jobs-at-across-the-globe-atg1687161333">Techical Business Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-across-the-globe-atg">
#                         Across The Globe (ATG)                    </a>
# </h4>
# </div>, <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-scientist-fresher-jobs-in-pathanamthitta-at-future-skills1687143219">Data Scientist</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-future-skills">
#                         Future Skills                    </a>
# </h4>
# </div>]

# %%
print(len(jobs))
# Out:
# 40

# %%
job=jobs[0]

# %%
job
# Out:
# <div class="company">
# <h3 class="heading_4_5 profile">
# <a class="view_detail_button" href="/job/detail/data-analyst-fresher-jobs-in-guwahati-at-primary-healthtech1687943819">Data Analyst</a> </h3>
# <h4 class="heading_6 company_name">
# <a class="link_display_like_text view_detail_button" href="/jobs/fresher-job-at-primary-healthtech">
#                         Primary Healthtech                    </a>
# </h4>
# </div>

# %%
job.text
# Out:
# '\n\nData Analyst \n\n\n                        Primary Healthtech                    \n\n'

# %%
name=content.find_all('div',{'class':'company'})
#print(name)
#print(type(name))
#name=name[0]
#name=name.text
len(name)
# Out:
# 40

# %%
salary=content.find_all('div',{'class':'item_body salary'})
#print(salary)
len(salary)
# Out:
# 40

# %%
experience=content.find_all('div',{'class':'item_body mobile-text'})
#print(experience)
len(experience)
# Out:
# 40

# %%
Jobs=[]
Salary=[]
Experience=[]

# %%
for i in name:
    Jobs.append(i.text)
    
for i in salary:
    Salary.append(i.text)
    
for i in experience:
    Experience.append(i.text)

# %%
data={'Jobs':Jobs,'Salary':Salary,'Experience':Experience}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#                                                  Jobs  \
# 0   \n\nData Analyst \n\n\n                       ...
# 1   \n\nArtificial Intelligence (AI) Executive \n\...
# 2   \n\nData Scientist \n\n\n                     ...
# 3   \n\nData Scientist \n\n\n                     ...
# 4   \n\nResearch Analyst \n\n\n                   ...
# 5   \n\nResearch Assistant \n\n\n                 ...
# 6   \n\nBusiness Analyst \n\n\n                   ...
# 7   \n\nComputer Vision & NLP - AI Engineer (Fresh...
# 8   \n\nBusiness Analyst \n\n\n                   ...
# 9   \n\nBehavioral Data Scientist \n\n\n          ...
# 10  \n\nMachine Learning Engineer \n\n\n          ...
# 11  \n\nMachine Learning Engineer \n\n\n          ...
# 12  \n\nBusiness Analyst \n\n\n                   ...
# 13  \n\nJunior Business Analyst \n\n\n            ...
# 14  \n\nExecutive - Analyst & Operations \n\n\n   ...
# 15  \n\nAssociate Data Scientist \n\n\n           ...
# 16  \n\nMachine Learning Developer (Python) \n\n\n...
# 17  \n\nTransforming India Initiative - Reimagine ...
# 18  \n\nProduction Technician \n\n\n              ...
# 19  \n\nData Scientist \n\n\n                     ...
# 20  \n\nData Scientist \n\n\n                     ...
# 21  \n\nFinancial Data Analyst \n\n\n             ...
# 22  \n\nBusiness Development Associate \n\n\n     ...
# 23  \n\nData Science & Machine Learning Trainer \n...
# 24  \n\nTechnical Research Engineer \n\n\n        ...
# 25  \n\nJunior Java Developer \n\n\n              ...
# 26  \n\nData Scientist Educationist \n\n\n        ...
# 27  \n\nJunior Machine Learning Specialist \n\n\n ...
# 28  \n\nMachine Learning Engineer \n\n\n          ...
# 29  \n\nOMNI SPORT LEADER \n\n\n                  ...
# 30  \n\nPython (AI/ML) Engineer \n\n\n            ...
# 31  \n\nAssociate Business Analyst \n\n\n         ...
# 32  \n\nIT Data Visualization Trainee \n\n\n      ...
# 33  \n\nIT Data Center Operations Associate \n\n\n...
# 34  \n\nQuality Assurance Analyst \n\n\n          ...
# 35  \n\nDatabase Building/Management Associate \n\...
# 36  \n\nIT Business Intelligence Analyst \n\n\n   ...
# 37  \n\nData Engineer \n\n\n                      ...
# 38  \n\nTechical Business Analyst \n\n\n          ...
# 39  \n\nData Scientist \n\n\n                     ...
#
#                                                Salary            Experience
# 0   \n                            ₹  2 LPA        ...  0-2 years experience
# 1   \n                            ₹  8 - 12 LPA   ...  0-5 years experience
# 2   \n                            ₹  6 - 8.5 LPA  ...  0-5 years experience
# 3   \n                            ₹  9 - 10 LPA   ...  0-5 years experience
# 4   \n                            ₹  2 LPA        ...  0-2 years experience
# 5   \n                            ₹  3 - 4 LPA    ...  0-2 years experience
# 6   \n                            ₹  2.4 - 3 LPA  ...  0-2 years experience
# 7   \n                            ₹  5 LPA        ...  0-5 years experience
# 8   \n                            ₹  3 - 5 LPA    ...  0-5 years experience
# 9   \n                            ₹  3 - 5 LPA    ...  0-5 years experience
# 10  \n                            ₹  10 - 55 LPA  ...  0-5 years experience
# 11  \n                            ₹  3 - 4 LPA    ...  0-2 years experience
# 12  \n                            ₹  2 - 3 LPA    ...  0-2 years experience
# 13  \n                            ₹  5 - 7 LPA    ...  0-5 years experience
# 14  \n                            ₹  2 - 4 LPA    ...  0-2 years experience
# 15  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 16  \n                            ₹  5 - 7 LPA    ...  0-5 years experience
# 17  \n                            ₹  2.35 - 2.75 L...  0-2 years experience
# 18  \n                            ₹  2 - 2.2 LPA  ...  0-2 years experience
# 19  \n                            ₹  3.6 LPA      ...  0-2 years experience
# 20  \n                            ₹  3 LPA        ...  0-2 years experience
# 21  \n                            ₹  3.6 LPA      ...  0-2 years experience
# 22  \n                            ₹  4.5 - 9 LPA  ...  0-5 years experience
# 23  \n                            ₹  2 LPA        ...  0-2 years experience
# 24  \n                            ₹  2 - 2.2 LPA  ...  0-2 years experience
# 25  \n                            ₹  4.5 - 6 LPA  ...  0-5 years experience
# 26  \n                            ₹  2.5 - 3.5 LPA...  0-2 years experience
# 27  \n                            ₹  2.5 - 3 LPA  ...  0-2 years experience
# 28  \n                            ₹  3.6 - 5 LPA  ...  0-5 years experience
# 29  \n                            ₹  3 - 3.5 LPA  ...  0-2 years experience
# 30  \n                            ₹  2 - 4 LPA    ...  0-2 years experience
# 31  \n                            ₹  3.6 - 4.2 LPA...  0-2 years experience
# 32  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 33  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 34  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 35  \n                            ₹  2.2 - 2.8 LPA...  0-2 years experience
# 36  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 37  \n                            ₹  4 - 6 LPA    ...  0-5 years experience
# 38  \n                            ₹  3 - 5 LPA    ...  0-5 years experience
# 39  \n                            ₹  3 - 5 LPA    ...  0-5 years experience

# %%
Df1=df.applymap(lambda x:x.replace('\n',''))

# %%
Df1
# Out:
#                                                  Jobs  \
# 0   Data Analyst                         Primary H...
# 1   Artificial Intelligence (AI) Executive        ...
# 2   Data Scientist                         Buddha ...
# 3   Data Scientist                         Shubh I...
# 4   Research Analyst                         Jade ...
# 5   Research Assistant                         Ind...
# 6   Business Analyst                         Vumon...
# 7   Computer Vision & NLP - AI Engineer (Fresher/E...
# 8   Business Analyst                         Futur...
# 9   Behavioral Data Scientist                     ...
# 10  Machine Learning Engineer                     ...
# 11  Machine Learning Engineer                     ...
# 12  Business Analyst                         Arth ...
# 13  Junior Business Analyst                       ...
# 14  Executive - Analyst & Operations              ...
# 15  Associate Data Scientist                      ...
# 16  Machine Learning Developer (Python)           ...
# 17  Transforming India Initiative - Reimagine Resp...
# 18  Production Technician                         ...
# 19  Data Scientist                         BlobCit...
# 20  Data Scientist                         Areete ...
# 21  Financial Data Analyst                        ...
# 22  Business Development Associate                ...
# 23  Data Science & Machine Learning Trainer       ...
# 24  Technical Research Engineer                   ...
# 25  Junior Java Developer                         ...
# 26  Data Scientist Educationist                   ...
# 27  Junior Machine Learning Specialist            ...
# 28  Machine Learning Engineer                     ...
# 29  OMNI SPORT LEADER                         Deca...
# 30  Python (AI/ML) Engineer                       ...
# 31  Associate Business Analyst                    ...
# 32  IT Data Visualization Trainee                 ...
# 33  IT Data Center Operations Associate           ...
# 34  Quality Assurance Analyst                     ...
# 35  Database Building/Management Associate        ...
# 36  IT Business Intelligence Analyst              ...
# 37  Data Engineer                         StudyMon...
# 38  Techical Business Analyst                     ...
# 39  Data Scientist                         Future ...
#
#                                                Salary            Experience
# 0                               ₹  2 LPA          ...  0-2 years experience
# 1                               ₹  8 - 12 LPA     ...  0-5 years experience
# 2                               ₹  6 - 8.5 LPA    ...  0-5 years experience
# 3                               ₹  9 - 10 LPA     ...  0-5 years experience
# 4                               ₹  2 LPA          ...  0-2 years experience
# 5                               ₹  3 - 4 LPA      ...  0-2 years experience
# 6                               ₹  2.4 - 3 LPA    ...  0-2 years experience
# 7                               ₹  5 LPA          ...  0-5 years experience
# 8                               ₹  3 - 5 LPA      ...  0-5 years experience
# 9                               ₹  3 - 5 LPA      ...  0-5 years experience
# 10                              ₹  10 - 55 LPA    ...  0-5 years experience
# 11                              ₹  3 - 4 LPA      ...  0-2 years experience
# 12                              ₹  2 - 3 LPA      ...  0-2 years experience
# 13                              ₹  5 - 7 LPA      ...  0-5 years experience
# 14                              ₹  2 - 4 LPA      ...  0-2 years experience
# 15                              ₹  4 - 6 LPA      ...  0-5 years experience
# 16                              ₹  5 - 7 LPA      ...  0-5 years experience
# 17                              ₹  2.35 - 2.75 LPA...  0-2 years experience
# 18                              ₹  2 - 2.2 LPA    ...  0-2 years experience
# 19                              ₹  3.6 LPA        ...  0-2 years experience
# 20                              ₹  3 LPA          ...  0-2 years experience
# 21                              ₹  3.6 LPA        ...  0-2 years experience
# 22                              ₹  4.5 - 9 LPA    ...  0-5 years experience
# 23                              ₹  2 LPA          ...  0-2 years experience
# 24                              ₹  2 - 2.2 LPA    ...  0-2 years experience
# 25                              ₹  4.5 - 6 LPA    ...  0-5 years experience
# 26                              ₹  2.5 - 3.5 LPA  ...  0-2 years experience
# 27                              ₹  2.5 - 3 LPA    ...  0-2 years experience
# 28                              ₹  3.6 - 5 LPA    ...  0-5 years experience
# 29                              ₹  3 - 3.5 LPA    ...  0-2 years experience
# 30                              ₹  2 - 4 LPA      ...  0-2 years experience
# 31                              ₹  3.6 - 4.2 LPA  ...  0-2 years experience
# 32                              ₹  4 - 6 LPA      ...  0-5 years experience
# 33                              ₹  4 - 6 LPA      ...  0-5 years experience
# 34                              ₹  4 - 6 LPA      ...  0-5 years experience
# 35                              ₹  2.2 - 2.8 LPA  ...  0-2 years experience
# 36                              ₹  4 - 6 LPA      ...  0-5 years experience
# 37                              ₹  4 - 6 LPA      ...  0-5 years experience
# 38                              ₹  3 - 5 LPA      ...  0-5 years experience
# 39                              ₹  3 - 5 LPA      ...  0-5 years experience

# %%
ss=r'[₹,-]'

# %%
Df2=Df1.applymap(lambda x:re.sub(ss,'',x))

# %%
Df2.head()
# Out:
#                                                 Jobs  \
# 0  Data Analyst                         Primary H...
# 1  Artificial Intelligence (AI) Executive        ...
# 2  Data Scientist                         Buddha ...
# 3  Data Scientist                         Shubh I...
# 4  Research Analyst                         Jade ...
#
#                                               Salary           Experience
# 0                                2 LPA           ...  02 years experience
# 1                                8  12 LPA       ...  05 years experience
# 2                                6  8.5 LPA      ...  05 years experience
# 3                                9  10 LPA       ...  05 years experience
# 4                                2 LPA           ...  02 years experience

# %%
Df2['Experience']=Df2['Experience'].str.replace('years experience','')
Df2['Salary']=Df2['Salary'].str.replace('LPA ...','')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_7112\122342500.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   Df2['Salary']=Df2['Salary'].str.replace('LPA ...','')

# %%
pattern = r'(\d+(?:\.\d+)?)'

# %%
Df2[['Min_Salary', 'Max_Salary']] = Df2['Salary'].str.extractall(pattern).unstack()

# %%
Df2
# Out:
#                                                  Jobs  \
# 0   Data Analyst                         Primary H...
# 1   Artificial Intelligence (AI) Executive        ...
# 2   Data Scientist                         Buddha ...
# 3   Data Scientist                         Shubh I...
# 4   Research Analyst                         Jade ...
# 5   Research Assistant                         Ind...
# 6   Business Analyst                         Vumon...
# 7   Computer Vision & NLP  AI Engineer (Fresher/Ex...
# 8   Business Analyst                         Futur...
# 9   Behavioral Data Scientist                     ...
# 10  Machine Learning Engineer                     ...
# 11  Machine Learning Engineer                     ...
# 12  Business Analyst                         Arth ...
# 13  Junior Business Analyst                       ...
# 14  Executive  Analyst & Operations               ...
# 15  Associate Data Scientist                      ...
# 16  Machine Learning Developer (Python)           ...
# 17  Transforming India Initiative  Reimagine Respo...
# 18  Production Technician                         ...
# 19  Data Scientist                         BlobCit...
# 20  Data Scientist                         Areete ...
# 21  Financial Data Analyst                        ...
# 22  Business Development Associate                ...
# 23  Data Science & Machine Learning Trainer       ...
# 24  Technical Research Engineer                   ...
# 25  Junior Java Developer                         ...
# 26  Data Scientist Educationist                   ...
# 27  Junior Machine Learning Specialist            ...
# 28  Machine Learning Engineer                     ...
# 29  OMNI SPORT LEADER                         Deca...
# 30  Python (AI/ML) Engineer                       ...
# 31  Associate Business Analyst                    ...
# 32  IT Data Visualization Trainee                 ...
# 33  IT Data Center Operations Associate           ...
# 34  Quality Assurance Analyst                     ...
# 35  Database Building/Management Associate        ...
# 36  IT Business Intelligence Analyst              ...
# 37  Data Engineer                         StudyMon...
# 38  Techical Business Analyst                     ...
# 39  Data Scientist                         Future ...
#
#                                                Salary Experience Min_Salary  \
# 0                                 2               ...        02           2
# 1                                 8  12           ...        05           8
# 2                                 6  8.5          ...        05           6
# 3                                 9  10           ...        05           9
# 4                                 2               ...        02           2
# 5                                 3  4            ...        02           3
# 6                                 2.4  3          ...        02         2.4
# 7                                 5               ...        05           5
# 8                                 3  5            ...        05           3
# 9                                 3  5            ...        05           3
# 10                                10  55          ...        05          10
# 11                                3  4            ...        02           3
# 12                                2  3            ...        02           2
# 13                                5  7            ...        05           5
# 14                                2  4            ...        02           2
# 15                                4  6            ...        05           4
# 16                                5  7            ...        05           5
# 17                                2.35  2.75      ...        02        2.35
# 18                                2  2.2          ...        02           2
# 19                                3.6             ...        02         3.6
# 20                                3               ...        02           3
# 21                                3.6             ...        02         3.6
# 22                                4.5  9          ...        05         4.5
# 23                                2               ...        02           2
# 24                                2  2.2          ...        02           2
# 25                                4.5  6          ...        05         4.5
# 26                                2.5  3.5        ...        02         2.5
# 27                                2.5  3          ...        02         2.5
# 28                                3.6  5          ...        05         3.6
# 29                                3  3.5          ...        02           3
# 30                                2  4            ...        02           2
# 31                                3.6  4.2        ...        02         3.6
# 32                                4  6            ...        05           4
# 33                                4  6            ...        05           4
# 34                                4  6            ...        05           4
# 35                                2.2  2.8        ...        02         2.2
# 36                                4  6            ...        05           4
# 37                                4  6            ...        05           4
# 38                                3  5            ...        05           3
# 39                                3  5            ...        05           3
#
#    Max_Salary
# 0         NaN
# 1          12
# 2         8.5
# 3          10
# 4         NaN
# 5           4
# 6           3
# 7         NaN
# 8           5
# 9           5
# 10         55
# 11          4
# 12          3
# 13          7
# 14          4
# 15          6
# 16          7
# 17       2.75
# 18        2.2
# 19        NaN
# 20        NaN
# 21        NaN
# 22          9
# 23        NaN
# 24        2.2
# 25          6
# 26        3.5
# 27          3
# 28          5
# 29        3.5
# 30          4
# 31        4.2
# 32          6
# 33          6
# 34          6
# 35        2.8
# 36          6
# 37          6
# 38          5
# 39          5

# %%
Df2.isnull().sum()
# Out:
# Jobs          0
# Salary        0
# Experience    0
# Min_Salary    0
# Max_Salary    7
# dtype: int64

# %%
Df2['Max_Salary']=Df2['Max_Salary'].bfill()

# %%
Df2['Salary']=Df2['Salary'].str.replace(',', '').str.split().apply(lambda x:[float(i) for i in x])

# %%
Df2['Avg_Salary']=Df2['Salary'].apply(lambda x:sum(x)/len(x))

# %%
Df2=Df2.drop('Salary',axis=1)

# %%
Df2
# Out:
#                                                  Jobs Experience Min_Salary  \
# 0   Data Analyst                         Primary H...        02           2
# 1   Artificial Intelligence (AI) Executive        ...        05           8
# 2   Data Scientist                         Buddha ...        05           6
# 3   Data Scientist                         Shubh I...        05           9
# 4   Research Analyst                         Jade ...        02           2
# 5   Research Assistant                         Ind...        02           3
# 6   Business Analyst                         Vumon...        02         2.4
# 7   Computer Vision & NLP  AI Engineer (Fresher/Ex...        05           5
# 8   Business Analyst                         Futur...        05           3
# 9   Behavioral Data Scientist                     ...        05           3
# 10  Machine Learning Engineer                     ...        05          10
# 11  Machine Learning Engineer                     ...        02           3
# 12  Business Analyst                         Arth ...        02           2
# 13  Junior Business Analyst                       ...        05           5
# 14  Executive  Analyst & Operations               ...        02           2
# 15  Associate Data Scientist                      ...        05           4
# 16  Machine Learning Developer (Python)           ...        05           5
# 17  Transforming India Initiative  Reimagine Respo...        02        2.35
# 18  Production Technician                         ...        02           2
# 19  Data Scientist                         BlobCit...        02         3.6
# 20  Data Scientist                         Areete ...        02           3
# 21  Financial Data Analyst                        ...        02         3.6
# 22  Business Development Associate                ...        05         4.5
# 23  Data Science & Machine Learning Trainer       ...        02           2
# 24  Technical Research Engineer                   ...        02           2
# 25  Junior Java Developer                         ...        05         4.5
# 26  Data Scientist Educationist                   ...        02         2.5
# 27  Junior Machine Learning Specialist            ...        02         2.5
# 28  Machine Learning Engineer                     ...        05         3.6
# 29  OMNI SPORT LEADER                         Deca...        02           3
# 30  Python (AI/ML) Engineer                       ...        02           2
# 31  Associate Business Analyst                    ...        02         3.6
# 32  IT Data Visualization Trainee                 ...        05           4
# 33  IT Data Center Operations Associate           ...        05           4
# 34  Quality Assurance Analyst                     ...        05           4
# 35  Database Building/Management Associate        ...        02         2.2
# 36  IT Business Intelligence Analyst              ...        05           4
# 37  Data Engineer                         StudyMon...        05           4
# 38  Techical Business Analyst                     ...        05           3
# 39  Data Scientist                         Future ...        05           3
#
#    Max_Salary  Avg_Salary
# 0          12        2.00
# 1          12       10.00
# 2         8.5        7.25
# 3          10        9.50
# 4           4        2.00
# 5           4        3.50
# 6           3        2.70
# 7           5        5.00
# 8           5        4.00
# 9           5        4.00
# 10         55       32.50
# 11          4        3.50
# 12          3        2.50
# 13          7        6.00
# 14          4        3.00
# 15          6        5.00
# 16          7        6.00
# 17       2.75        2.55
# 18        2.2        2.10
# 19          9        3.60
# 20          9        3.00
# 21          9        3.60
# 22          9        6.75
# 23        2.2        2.00
# 24        2.2        2.10
# 25          6        5.25
# 26        3.5        3.00
# 27          3        2.75
# 28          5        4.30
# 29        3.5        3.25
# 30          4        3.00
# 31        4.2        3.90
# 32          6        5.00
# 33          6        5.00
# 34          6        5.00
# 35        2.8        2.50
# 36          6        5.00
# 37          6        5.00
# 38          5        4.00
# 39          5        4.00

# %%
Df2['Min_Salary']=Df2['Min_Salary'].str.replace(',', '').str.split().apply(lambda x:[float(i) for i in x])

# %%
Df2['Min_Salary']=Df2['Min_Salary'].apply(lambda x:sum(x)/len(x))

# %%
Df2
# Out:
#                                                  Jobs Experience  Min_Salary  \
# 0   Data Analyst                         Primary H...        02         2.00
# 1   Artificial Intelligence (AI) Executive        ...        05         8.00
# 2   Data Scientist                         Buddha ...        05         6.00
# 3   Data Scientist                         Shubh I...        05         9.00
# 4   Research Analyst                         Jade ...        02         2.00
# 5   Research Assistant                         Ind...        02         3.00
# 6   Business Analyst                         Vumon...        02         2.40
# 7   Computer Vision & NLP  AI Engineer (Fresher/Ex...        05         5.00
# 8   Business Analyst                         Futur...        05         3.00
# 9   Behavioral Data Scientist                     ...        05         3.00
# 10  Machine Learning Engineer                     ...        05        10.00
# 11  Machine Learning Engineer                     ...        02         3.00
# 12  Business Analyst                         Arth ...        02         2.00
# 13  Junior Business Analyst                       ...        05         5.00
# 14  Executive  Analyst & Operations               ...        02         2.00
# 15  Associate Data Scientist                      ...        05         4.00
# 16  Machine Learning Developer (Python)           ...        05         5.00
# 17  Transforming India Initiative  Reimagine Respo...        02         2.35
# 18  Production Technician                         ...        02         2.00
# 19  Data Scientist                         BlobCit...        02         3.60
# 20  Data Scientist                         Areete ...        02         3.00
# 21  Financial Data Analyst                        ...        02         3.60
# 22  Business Development Associate                ...        05         4.50
# 23  Data Science & Machine Learning Trainer       ...        02         2.00
# 24  Technical Research Engineer                   ...        02         2.00
# 25  Junior Java Developer                         ...        05         4.50
# 26  Data Scientist Educationist                   ...        02         2.50
# 27  Junior Machine Learning Specialist            ...        02         2.50
# 28  Machine Learning Engineer                     ...        05         3.60
# 29  OMNI SPORT LEADER                         Deca...        02         3.00
# 30  Python (AI/ML) Engineer                       ...        02         2.00
# 31  Associate Business Analyst                    ...        02         3.60
# 32  IT Data Visualization Trainee                 ...        05         4.00
# 33  IT Data Center Operations Associate           ...        05         4.00
# 34  Quality Assurance Analyst                     ...        05         4.00
# 35  Database Building/Management Associate        ...        02         2.20
# 36  IT Business Intelligence Analyst              ...        05         4.00
# 37  Data Engineer                         StudyMon...        05         4.00
# 38  Techical Business Analyst                     ...        05         3.00
# 39  Data Scientist                         Future ...        05         3.00
#
#    Max_Salary  Avg_Salary
# 0          12        2.00
# 1          12       10.00
# 2         8.5        7.25
# 3          10        9.50
# 4           4        2.00
# 5           4        3.50
# 6           3        2.70
# 7           5        5.00
# 8           5        4.00
# 9           5        4.00
# 10         55       32.50
# 11          4        3.50
# 12          3        2.50
# 13          7        6.00
# 14          4        3.00
# 15          6        5.00
# 16          7        6.00
# 17       2.75        2.55
# 18        2.2        2.10
# 19          9        3.60
# 20          9        3.00
# 21          9        3.60
# 22          9        6.75
# 23        2.2        2.00
# 24        2.2        2.10
# 25          6        5.25
# 26        3.5        3.00
# 27          3        2.75
# 28          5        4.30
# 29        3.5        3.25
# 30          4        3.00
# 31        4.2        3.90
# 32          6        5.00
# 33          6        5.00
# 34          6        5.00
# 35        2.8        2.50
# 36          6        5.00
# 37          6        5.00
# 38          5        4.00
# 39          5        4.00

# %%
Df2['Max_Salary']=Df2['Max_Salary'].str.replace(',', '').str.split().apply(lambda x:[float(i) for i in x])

# %%
Df2['Max_Salary']=Df2['Max_Salary'].apply(lambda x:sum(x)/len(x))

# %%
Df2
# Out:
#                                                  Jobs Experience  Min_Salary  \
# 0   Data Analyst                         Primary H...        02         2.00
# 1   Artificial Intelligence (AI) Executive        ...        05         8.00
# 2   Data Scientist                         Buddha ...        05         6.00
# 3   Data Scientist                         Shubh I...        05         9.00
# 4   Research Analyst                         Jade ...        02         2.00
# 5   Research Assistant                         Ind...        02         3.00
# 6   Business Analyst                         Vumon...        02         2.40
# 7   Computer Vision & NLP  AI Engineer (Fresher/Ex...        05         5.00
# 8   Business Analyst                         Futur...        05         3.00
# 9   Behavioral Data Scientist                     ...        05         3.00
# 10  Machine Learning Engineer                     ...        05        10.00
# 11  Machine Learning Engineer                     ...        02         3.00
# 12  Business Analyst                         Arth ...        02         2.00
# 13  Junior Business Analyst                       ...        05         5.00
# 14  Executive  Analyst & Operations               ...        02         2.00
# 15  Associate Data Scientist                      ...        05         4.00
# 16  Machine Learning Developer (Python)           ...        05         5.00
# 17  Transforming India Initiative  Reimagine Respo...        02         2.35
# 18  Production Technician                         ...        02         2.00
# 19  Data Scientist                         BlobCit...        02         3.60
# 20  Data Scientist                         Areete ...        02         3.00
# 21  Financial Data Analyst                        ...        02         3.60
# 22  Business Development Associate                ...        05         4.50
# 23  Data Science & Machine Learning Trainer       ...        02         2.00
# 24  Technical Research Engineer                   ...        02         2.00
# 25  Junior Java Developer                         ...        05         4.50
# 26  Data Scientist Educationist                   ...        02         2.50
# 27  Junior Machine Learning Specialist            ...        02         2.50
# 28  Machine Learning Engineer                     ...        05         3.60
# 29  OMNI SPORT LEADER                         Deca...        02         3.00
# 30  Python (AI/ML) Engineer                       ...        02         2.00
# 31  Associate Business Analyst                    ...        02         3.60
# 32  IT Data Visualization Trainee                 ...        05         4.00
# 33  IT Data Center Operations Associate           ...        05         4.00
# 34  Quality Assurance Analyst                     ...        05         4.00
# 35  Database Building/Management Associate        ...        02         2.20
# 36  IT Business Intelligence Analyst              ...        05         4.00
# 37  Data Engineer                         StudyMon...        05         4.00
# 38  Techical Business Analyst                     ...        05         3.00
# 39  Data Scientist                         Future ...        05         3.00
#
#     Max_Salary  Avg_Salary
# 0        12.00        2.00
# 1        12.00       10.00
# 2         8.50        7.25
# 3        10.00        9.50
# 4         4.00        2.00
# 5         4.00        3.50
# 6         3.00        2.70
# 7         5.00        5.00
# 8         5.00        4.00
# 9         5.00        4.00
# 10       55.00       32.50
# 11        4.00        3.50
# 12        3.00        2.50
# 13        7.00        6.00
# 14        4.00        3.00
# 15        6.00        5.00
# 16        7.00        6.00
# 17        2.75        2.55
# 18        2.20        2.10
# 19        9.00        3.60
# 20        9.00        3.00
# 21        9.00        3.60
# 22        9.00        6.75
# 23        2.20        2.00
# 24        2.20        2.10
# 25        6.00        5.25
# 26        3.50        3.00
# 27        3.00        2.75
# 28        5.00        4.30
# 29        3.50        3.25
# 30        4.00        3.00
# 31        4.20        3.90
# 32        6.00        5.00
# 33        6.00        5.00
# 34        6.00        5.00
# 35        2.80        2.50
# 36        6.00        5.00
# 37        6.00        5.00
# 38        5.00        4.00
# 39        5.00        4.00

# %% [markdown]
# # Data Scientist Jobs

# %%
DS=Df2[Df2.Jobs.str.contains('Data Scientist',case=False)]

# %%
DS
# Out:
#                                                  Jobs Experience  Min_Salary  \
# 2   Data Scientist                         Buddha ...        05          6.0
# 3   Data Scientist                         Shubh I...        05          9.0
# 9   Behavioral Data Scientist                     ...        05          3.0
# 15  Associate Data Scientist                      ...        05          4.0
# 19  Data Scientist                         BlobCit...        02          3.6
# 20  Data Scientist                         Areete ...        02          3.0
# 26  Data Scientist Educationist                   ...        02          2.5
# 39  Data Scientist                         Future ...        05          3.0
#
#     Max_Salary  Avg_Salary
# 2          8.5        7.25
# 3         10.0        9.50
# 9          5.0        4.00
# 15         6.0        5.00
# 19         9.0        3.60
# 20         9.0        3.00
# 26         3.5        3.00
# 39         5.0        4.00

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(DS['Avg_Salary'],labels=DS['Jobs'],autopct='%1.1f%%',wedgeprops={'edgecolor':'k'})
plt.axis('equal')
plt.show()

# %% [markdown]
# # Data Analyst Jobs

# %%
DA=Df2[Df2.Jobs.str.contains('Analyst',case=False)]

# %%
DA
# Out:
#                                                  Jobs Experience  Min_Salary  \
# 0   Data Analyst                         Primary H...        02          2.0
# 4   Research Analyst                         Jade ...        02          2.0
# 6   Business Analyst                         Vumon...        02          2.4
# 8   Business Analyst                         Futur...        05          3.0
# 12  Business Analyst                         Arth ...        02          2.0
# 13  Junior Business Analyst                       ...        05          5.0
# 14  Executive  Analyst & Operations               ...        02          2.0
# 21  Financial Data Analyst                        ...        02          3.6
# 31  Associate Business Analyst                    ...        02          3.6
# 34  Quality Assurance Analyst                     ...        05          4.0
# 36  IT Business Intelligence Analyst              ...        05          4.0
# 38  Techical Business Analyst                     ...        05          3.0
#
#     Max_Salary  Avg_Salary
# 0         12.0         2.0
# 4          4.0         2.0
# 6          3.0         2.7
# 8          5.0         4.0
# 12         3.0         2.5
# 13         7.0         6.0
# 14         4.0         3.0
# 21         9.0         3.6
# 31         4.2         3.9
# 34         6.0         5.0
# 36         6.0         5.0
# 38         5.0         4.0

# %%
plt.pie(DA[''],labels=DA['Jobs'],autopct='%1.1f%%',wedgeprops={'edgecolor':'k'})
plt.axis('equal')
plt.show()

# %% [markdown]
# # ML Jobs

# %%
ML=Df2[Df2.Jobs.str.contains('Engineer',case=False)]

# %%
ML
# Out:
#                                                  Jobs Experience  Min_Salary  \
# 7   Computer Vision & NLP  AI Engineer (Fresher/Ex...        05          5.0
# 10  Machine Learning Engineer                     ...        05         10.0
# 11  Machine Learning Engineer                     ...        02          3.0
# 24  Technical Research Engineer                   ...        02          2.0
# 28  Machine Learning Engineer                     ...        05          3.6
# 30  Python (AI/ML) Engineer                       ...        02          2.0
# 37  Data Engineer                         StudyMon...        05          4.0
#
#     Max_Salary  Avg_Salary
# 7          5.0         5.0
# 10        55.0        32.5
# 11         4.0         3.5
# 24         2.2         2.1
# 28         5.0         4.3
# 30         4.0         3.0
# 37         6.0         5.0

# %%
plt.pie(ML['Max_Salary'],labels=ML['Jobs'],autopct='%1.1f%%',wedgeprops={'edgecolor':'k'})
plt.axis('equal')
plt.show()
